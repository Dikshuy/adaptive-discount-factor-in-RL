# %%
import os
import sys
import logging
import logging.config
import gymnasium as gym
from datetime import datetime as dt
from gym_simplegrid.envs import SimpleGridEnv
from gymnasium.utils.save_video import save_video

from matplotlib import pyplot as plt

# %%
obstacle_map = [
    "00000100000",
    "00020100000",
    "02220000000",
    "00020102220",
    "00000100000",
    "11110111011",
    "20000100000",
    "00202102200",
    "00200102000",
    "00020002000",
    "00000100000",
]

# %%
obstacle_map = [
    "00000",
    "00000",
    "00000",
    "00000",
    "00000",
]

length = len(obstacle_map)
width = len(obstacle_map[0])

options ={
    'start_loc': (length - 1, 0),
    'goal_loc': (0, width - 1)
}
    


env = gym.make(
    'SimpleGrid-v0', 
    obstacle_map=obstacle_map, 
    render_mode='rgb_array'
)

obs, info = env.reset(seed=1, options=options)

# %%
obstacle_map = [
    "00000",
    "00020",
    "00000",
    "00200",
    "00002",
]

length = len(obstacle_map)
width = len(obstacle_map[0])

options ={
    'start_loc': (length - 1, 0),
    'goal_loc': (0, width - 1)
}
    


env = gym.make(
    'SimpleGrid-v0', 
    obstacle_map=obstacle_map, 
    render_mode='rgb_array'
)

obs, info = env.reset(seed=1, options=options)

# %%
obstacle_map = [
    "00000",
    "02220",
    "00000",
    "02200",
    "00002",
]

length = len(obstacle_map)
width = len(obstacle_map[0])

options ={
    'start_loc': (length - 1, 0),
    'goal_loc': (0, width - 1)
}


env = gym.make(
    'SimpleGrid-v0', 
    obstacle_map=obstacle_map, 
    render_mode='rgb_array'
)

obs, info = env.reset(seed=1, options=options)

# %%
obstacle_map = [
    "00000",
    "00000",
    "00000",
    "00000",
    "00000",
    "11011",
    "00000",
    "00000",
    "00000",
    "00000",
    "00000",
    "00000",
]

length = len(obstacle_map)
width = len(obstacle_map[0])

options ={
    'start_loc': (length - 1, 0),
    'goal_loc': (0, width - 1)
}
    


env = gym.make(
    'SimpleGrid-v0', 
    obstacle_map=obstacle_map, 
    render_mode='rgb_array'
)

obs, info = env.reset(seed=1, options=options)

# %%
obstacle_map = [
    "00000",
    "00200",
    "00000",
    "02220",
    "00000",
    "11011",
    "02000",
    "00020",
    "00000",
    "00200",
    "00000",
]

length = len(obstacle_map)
width = len(obstacle_map[0])

options ={
    'start_loc': (length - 1, 0),
    'goal_loc': (0, width - 1)
}
    


env = gym.make(
    'SimpleGrid-v0', 
    obstacle_map=obstacle_map, 
    render_mode='rgb_array'
)

obs, info = env.reset(seed=1, options=options)

# %%
obstacle_map = [
    "00000",
    "02222",
    "00000",
    "02220",
    "00000",
    "11011",
    "02000",
    "00220",
    "00000",
    "00220",
    "00000",
]

length = len(obstacle_map)
width = len(obstacle_map[0])

options ={
    'start_loc': (length - 1, 0),
    'goal_loc': (0, width - 1)
}
    


env = gym.make(
    'SimpleGrid-v0', 
    obstacle_map=obstacle_map, 
    render_mode='rgb_array'
)

obs, info = env.reset(seed=1, options=options)

# %%
obstacle_map = [
    "00000100000",
    "00000100000",
    "00000100000",
    "00000000000",
    "00000100000",
    "11011111101",
    "00000100000",
    "00000100000",
    "00000100000",
    "00000000000",
    "00000100000",
]

length = len(obstacle_map)
width = len(obstacle_map[0])

options ={
    'start_loc': (length - 1, 0),
    'goal_loc': (0, width - 1)
}
    


env = gym.make(
    'SimpleGrid-v0', 
    obstacle_map=obstacle_map, 
    render_mode='rgb_array'
)

obs, info = env.reset(seed=1, options=options)

# %%
obstacle_map = [
    "00000100000",
    "00200100022",
    "00000100000",
    "02220000020",
    "00000100000",
    "11011111101",
    "02000100000",
    "00020102020",
    "00000100000",
    "00200002000",
    "00000100000",
]

length = len(obstacle_map)
width = len(obstacle_map[0])

options ={
    'start_loc': (length - 1, 0),
    'goal_loc': (0, width - 1)
}
    


env = gym.make(
    'SimpleGrid-v0', 
    obstacle_map=obstacle_map, 
    render_mode='rgb_array'
)

obs, info = env.reset(seed=1, options=options)

# %%
obstacle_map = [
    "00000100000",
    "02222100022",
    "00000120002",
    "02220002020",
    "00000100000",
    "11011111101",
    "02000100200",
    "00220102020",
    "00000100000",
    "00220002002",
    "00000100002",
]

length = len(obstacle_map)
width = len(obstacle_map[0])

options ={
    'start_loc': (length - 1, 0),
    'goal_loc': (0, width - 1)
}
    


env = gym.make(
    'SimpleGrid-v0', 
    obstacle_map=obstacle_map, 
    render_mode='rgb_array'
)

obs, info = env.reset(seed=1, options=options)

# %%
print(env.step(0))
plt.imshow(env.render())
# Out:
# (99, 0.0, False, False, {'agent_xy': (9, 0), 'n_iter': 1})

# %%
print(env.step(3))
plt.imshow(env.render())
# Out:
# (100, 0.0, False, False, {'agent_xy': (9, 1), 'n_iter': 2})

# %%
print(env.step(3))
plt.imshow(env.render())
# Out:
# (101, -5.0, False, False, {'agent_xy': (9, 2), 'n_iter': 3})

# %%
print(env.step(1))
print(env.step(1))
plt.imshow(env.render())
# Out:
# (112, 0.0, False, False, {'agent_xy': (10, 2), 'n_iter': 4})
# (112, -1.0, False, False, {'agent_xy': (10, 2), 'n_iter': 5})

# %%
print(env.step(2))
print(env.step(2))
print(env.step(2))
plt.imshow(env.render())
# Out:
# (111, 0.0, False, False, {'agent_xy': (10, 1), 'n_iter': 6})
# (110, 0.0, False, False, {'agent_xy': (10, 0), 'n_iter': 7})
# (110, -1.0, False, False, {'agent_xy': (10, 0), 'n_iter': 8})

# %%
print(env.step(3))
print(env.step(3))
print(env.step(3))
print(env.step(3))
print(env.step(3))
plt.imshow(env.render())
# Out:
# (111, 0.0, False, False, {'agent_xy': (10, 1), 'n_iter': 9})
# (112, 0.0, False, False, {'agent_xy': (10, 2), 'n_iter': 10})
# (113, 0.0, False, False, {'agent_xy': (10, 3), 'n_iter': 11})
# (114, 0.0, False, False, {'agent_xy': (10, 4), 'n_iter': 12})
# (114, -1.0, False, False, {'agent_xy': (10, 4), 'n_iter': 13})

# %%
print(env.step(0))
print(env.step(3))
print(env.step(3))
print(env.step(3))
print(env.step(3))
print(env.step(3))
print(env.step(0))
print(env.step(0))
print(env.step(0))
print(env.step(0))
print(env.step(0))
print(env.step(0))
print(env.step(0))
print(env.step(0))
print(env.step(0))
plt.imshow(env.render())
# Out:
# (103, 0.0, False, False, {'agent_xy': (9, 4), 'n_iter': 14})
# (104, 0.0, False, False, {'agent_xy': (9, 5), 'n_iter': 15})
# (105, 0.0, False, False, {'agent_xy': (9, 6), 'n_iter': 16})
# (106, -5.0, False, False, {'agent_xy': (9, 7), 'n_iter': 17})
# (107, 0.0, False, False, {'agent_xy': (9, 8), 'n_iter': 18})
# (108, 0.0, False, False, {'agent_xy': (9, 9), 'n_iter': 19})
# (97, 0.0, False, False, {'agent_xy': (8, 9), 'n_iter': 20})
# (86, -5.0, False, False, {'agent_xy': (7, 9), 'n_iter': 21})
# (75, 0.0, False, False, {'agent_xy': (6, 9), 'n_iter': 22})
# (64, 0.0, False, False, {'agent_xy': (5, 9), 'n_iter': 23})
# (53, 0.0, False, False, {'agent_xy': (4, 9), 'n_iter': 24})
# (42, -5.0, False, False, {'agent_xy': (3, 9), 'n_iter': 25})
# (31, 0.0, False, False, {'agent_xy': (2, 9), 'n_iter': 26})
# (20, -5.0, False, False, {'agent_xy': (1, 9), 'n_iter': 27})
# (9, 0.0, False, False, {'agent_xy': (0, 9), 'n_iter': 28})

# %%
print(env.step(3))
plt.imshow(env.render())
# Out:
# (10, 1.0, True, False, {'agent_xy': (0, 10), 'n_iter': 29})
